# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("owid-covid-data.csv")

# %%
df.shape
# Out:
# (51371, 41)

# %%
df.head()
# Out:
#   iso_code      continent location        date  total_cases  new_cases  \
# 0      ABW  North America    Aruba  2020-03-13          2.0        2.0
# 1      ABW  North America    Aruba  2020-03-19          NaN        NaN
# 2      ABW  North America    Aruba  2020-03-20          4.0        2.0
# 3      ABW  North America    Aruba  2020-03-21          NaN        NaN
# 4      ABW  North America    Aruba  2020-03-22          NaN        NaN
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1               0.286           NaN         NaN                  0.0  ...
# 2               0.286           NaN         0.0                  0.0  ...
# 3               0.286           NaN         NaN                  0.0  ...
# 4               0.286           NaN         NaN                  0.0  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
df[['location', 'total_cases', 'total_deaths', 'total_deaths_per_million', 'total_tests_per_thousand', 'population', 'median_age', 'aged_65_older']].head()
# Out:
#   location  total_cases  total_deaths  total_deaths_per_million  \
# 0    Aruba          2.0           NaN                       NaN
# 1    Aruba          NaN           NaN                       NaN
# 2    Aruba          4.0           NaN                       NaN
# 3    Aruba          NaN           NaN                       NaN
# 4    Aruba          NaN           NaN                       NaN
#
#    total_tests_per_thousand  population  median_age  aged_65_older
# 0                       NaN    106766.0        41.2         13.085
# 1                       NaN    106766.0        41.2         13.085
# 2                       NaN    106766.0        41.2         13.085
# 3                       NaN    106766.0        41.2         13.085
# 4                       NaN    106766.0        41.2         13.085

# %%
covid_df = df[['continent', 'location','total_deaths','date', 'total_deaths_per_million','stringency_index', 'population_density', 'median_age', 'gdp_per_capita', 'aged_65_older', 'life_expectancy', 'human_development_index', 'total_cases',  'stringency_index', 'population_density', 'median_age', 'gdp_per_capita', 'aged_65_older', 'life_expectancy', 'human_development_index', 'total_cases']]

# %%
covid_df = covid_df[covid_df.date=="2020-10-20"]

# %%
covid_df.head()
# Out:
#           continent     location  total_deaths        date  \
# 216   North America        Aruba          34.0  2020-10-20
# 511            Asia  Afghanistan        1497.0  2020-10-20
# 724          Africa       Angola         247.0  2020-10-20
# 932   North America     Anguilla           NaN  2020-10-20
# 1158         Europe      Albania         454.0  2020-10-20
#
#       total_deaths_per_million  stringency_index  population_density  \
# 216                    318.453               NaN             584.800
# 511                     38.455               NaN              54.422
# 724                      7.515               NaN              23.890
# 932                        NaN               NaN                 NaN
# 1158                   157.759               NaN             104.871
#
#       median_age  gdp_per_capita  aged_65_older  ...  human_development_index  \
# 216         41.2       35973.781         13.085  ...                      NaN
# ...

# %%
covid_df.columns
# Out:
# Index(['continent', 'location', 'total_deaths', 'date',
#        'total_deaths_per_million', 'stringency_index', 'population_density',
#        'median_age', 'gdp_per_capita', 'aged_65_older', 'life_expectancy',
#        'human_development_index', 'total_cases', 'stringency_index',
#        'population_density', 'median_age', 'gdp_per_capita', 'aged_65_older',
#        'life_expectancy', 'human_development_index', 'total_cases'],
#       dtype='object')

# %%
covid_df.groupby(['continent'])['total_deaths'].sum()
# Out:
# continent
# Africa            39931.0
# Asia             225893.0
# Europe           190377.0
# North America    331100.0
# Oceania            1021.0
# South America    280601.0
# Name: total_deaths, dtype: float64

# %%
plt.figure(figsize=(20,10))
g = sns.barplot(y='location', x='total_deaths', data = covid_df[covid_df['continent']=='South America'].sort_values('total_deaths', ascending=False), estimator=sum)
#plt.show()
plt.title('Number of Covid-19 Deaths')
plt.ylabel('Number of Deaths')
plt.xlabel('Countries')
plt.show()

# %%
plt.figure(figsize=(20,10))
g = sns.barplot(y='location', x='total_deaths', data = covid_df[covid_df['continent']=='North America'].sort_values('total_deaths', ascending=False), estimator=sum)
#plt.show()
plt.title('Number of Covid-19 Deaths')
plt.ylabel('Number of Deaths')
plt.xlabel('Countries')
plt.show()

# %%
plt.figure(figsize=(20,10))
g = sns.barplot(y='location', x='total_deaths', data = covid_df[covid_df['continent']=='Africa'].sort_values('total_deaths', ascending=False), estimator=sum)
#plt.show()
plt.title('Number of Covid-19 Deaths')
plt.ylabel('Number of Deaths')
plt.xlabel('Countries')
plt.show()

# %%
plt.figure(figsize=(20,10))
g = sns.barplot(y='location', x='total_deaths', data = covid_df[covid_df['continent']=='Asia'].sort_values('total_deaths', ascending=False), estimator=sum)
#plt.show()
plt.title('Number of Covid-19 Deaths')
plt.ylabel('Number of Deaths')
plt.xlabel('Countries')
plt.show()

# %%
plt.figure(figsize=(20,10))
g = sns.barplot(y='location', x='total_deaths', data = covid_df[covid_df['continent']=='Europe'].sort_values('total_deaths', ascending=False), estimator=sum)
#plt.show()
plt.title('Number of Covid-19 Deaths')
plt.ylabel('Number of Deaths')
plt.xlabel('Countries')
plt.show()

# %%
plt.figure(figsize=(20,10))
g = sns.barplot(y='location', x='total_deaths', data = covid_df[covid_df['continent']=='Oceania'].sort_values('total_deaths', ascending=False), estimator=sum)
#plt.show()
plt.title('Number of Covid-19 Deaths')
plt.ylabel('Number of Deaths')
plt.xlabel('Countries')
plt.show()

# %%
imr_df = pd.read_csv("imr_jpr_2_7_07.csv")

# %%
imr_df.head()
# Out:
#   abbreva  ccode  year  regiona               countryname   ccyr  IMRSOURCE  \
# 0     USA      2  1816        5  united states of america  21816        NaN
# 1     USA      2  1817        5  united states of america  21817        NaN
# 2     USA      2  1818        5  united states of america  21818        NaN
# 3     USA      2  1819        5  united states of america  21819        NaN
# 4     USA      2  1820        5  united states of america  21820        NaN
#
#    IMR  numstate     w
# 0  NaN        23  0.75
# 1  NaN        23  0.75
# 2  NaN        23  0.75
# 3  NaN        23  0.75
# 4  NaN        23  0.75

# %%
imr_df.columns
# Out:
# Index(['abbreva', 'ccode', 'year', 'regiona', 'countryname', 'ccyr',
#        'IMRSOURCE', 'IMR', 'numstate', 'w'],
#       dtype='object')

# %%
imr_df = imr_df[['countryname', 'regiona', 'year', 'IMR']]

# %%
imr_df = imr_df[imr_df.year<=1970]

# %%
imr_df.tail()
# Out:
#        countryname  regiona  year   IMR
# 13021  new zealand        4  1967  18.0
# 13022  new zealand        4  1968  19.0
# 13023  new zealand        4  1969  17.0
# 13024  new zealand        4  1970  17.0
# 13111         fiji        4  1970  45.0

# %%
imr_df = imr_df.groupby(['countryname']).mean().reset_index()

# %%
imr_df.head()
# Out:
#    countryname  regiona         year         IMR
# 0  afghanistan      4.0  1945.000000  207.157143
# 1      albania      1.0  1942.037736   83.309524
# 2      algeria      2.0  1966.000000   98.777778
# 3    argentina      5.0  1905.500000  125.783784
# 4    australia      4.0  1945.000000   33.784314

# %%
imr_df.reset_index(level=0, inplace=True)

# %%
plt.figure(figsize=(20,30))
g = sns.barplot(y='countryname', x='IMR', data = imr_df.sort_values(['IMR']))

# %%
life_df = pd.read_csv("life-expectancy-vs-health-expenditure.csv")
life_df.head()
# Out:
#         Entity      Code  Year  Total population (Gapminder, HYDE & UN)  \
# 0     Abkhazia  OWID_ABK  2015                                      NaN
# 1  Afghanistan       AFG  1800                                3280000.0
# 2  Afghanistan       AFG  1801                                3280000.0
# 3  Afghanistan       AFG  1802                                3280000.0
# 4  Afghanistan       AFG  1803                                3280000.0
#
#   Continent Health Expenditure and Financing (per capita) (OECDstat (2017))  \
# 0      Asia                                                NaN
# 1       NaN                                                NaN
# 2       NaN                                                NaN
# 3       NaN                                                NaN
# 4       NaN                                                NaN
#
#    Life expectancy at birth, total (years)
# 0                                      NaN
# 1                                      NaN
# ...

# %%
life_df = life_df[(life_df.Year<=1970) & (life_df.Year>=1920)]
life_df.head()
# Out:
#           Entity Code  Year  Total population (Gapminder, HYDE & UN)  \
# 121  Afghanistan  AFG  1920                                5813814.0
# 122  Afghanistan  AFG  1921                                5869464.0
# 123  Afghanistan  AFG  1922                                5925647.0
# 124  Afghanistan  AFG  1923                                5982368.0
# 125  Afghanistan  AFG  1924                                6039631.0
#
#     Continent Health Expenditure and Financing (per capita) (OECDstat (2017))  \
# 121       NaN                                                NaN
# 122       NaN                                                NaN
# 123       NaN                                                NaN
# 124       NaN                                                NaN
# 125       NaN                                                NaN
#
#      Life expectancy at birth, total (years)
# 121                                      NaN
# 122                                      NaN
# ...

# %%
life_df.columns
# Out:
# Index(['Entity', 'Code', 'Year', 'Total population (Gapminder, HYDE & UN)',
#        'Continent',
#        'Health Expenditure and Financing (per capita) (OECDstat (2017))',
#        'Life expectancy at birth, total (years)'],
#       dtype='object')

# %%
life_df = life_df.groupby(['Entity', 'Code'])[['Life expectancy at birth, total (years)', 'Total population (Gapminder, HYDE & UN)']].mean().reset_index()
life_df.head()
# Out:
#            Entity Code  Life expectancy at birth, total (years)  \
# 0     Afghanistan  AFG                                34.490455
# 1         Albania  ALB                                65.318091
# 2         Algeria  DZA                                48.327636
# 3  American Samoa  ASM                                      NaN
# 4         Andorra  AND                                      NaN
#
#    Total population (Gapminder, HYDE & UN)
# 0                             7.713939e+06
# 1                             1.315618e+06
# 2                             8.941043e+06
# 3                             2.180952e+04
# 4                             9.005020e+03

# %%
plt.figure(figsize = (20, 40))
sns.barplot(x='Life expectancy at birth, total (years)', y='Entity', data = life_df.sort_values('Life expectancy at birth, total (years)'))
plt.show()

# %%
# list of countries that are observed in COVID_DF but absent in LIFE_DF
new_list = [
    list(set(covid_df.location).difference(life_df.Entity))
]
new_list
# Out:
# [['Kosovo', 'Jersey', 'International', 'Guernsey']]

# %%
# list of countries that are observed in life_Df but are not in COVID_DF
new_list2 = [
    list(set(life_df.Entity).difference(covid_df.location))
]

new_list2
# Out:
# [['Channel Islands',
#   'Kiribati',
#   'Niue',
#   'Vanuatu',
#   'Macao',
#   'Tokelau',
#   'Wallis and Futuna',
#   'French Guiana',
#   'Martinique',
#   'Spain',
#   'Turkmenistan',
#   'Saint Pierre and Miquelon',
#   'Sweden',
#   'North Korea',
#   'Tuvalu',
#   'American Samoa',
#   'Samoa',
#   'Micronesia (country)',
#   'Hong Kong',
#   'Saint Helena',
#   'Mayotte',
#   'Marshall Islands',
#   'Palau',
#   'Guadeloupe',
#   'Cook Islands',
#   'Nauru',
#   'Reunion',
#   'Tonga',
#   'Saint Martin (French part)',
#   'Belgium']]

# %%
# Since the COVID_DF is the main dataset, we merge life_df to it. 
covid_df = pd.merge(covid_df, life_df, left_on='location', right_on='Entity')
covid_df.head()
# Out:
#        continent     location  total_deaths        date  \
# 0  North America        Aruba          34.0  2020-10-20
# 1           Asia  Afghanistan        1497.0  2020-10-20
# 2         Africa       Angola         247.0  2020-10-20
# 3  North America     Anguilla           NaN  2020-10-20
# 4         Europe      Albania         454.0  2020-10-20
#
#    total_deaths_per_million  stringency_index  population_density  median_age  \
# 0                   318.453               NaN             584.800        41.2
# 1                    38.455               NaN              54.422        18.6
# 2                     7.515               NaN              23.890        16.8
# 3                       NaN               NaN                 NaN         NaN
# 4                   157.759               NaN             104.871        38.0
#
#    gdp_per_capita  aged_65_older  ...  median_age  gdp_per_capita  \
# 0       35973.781         13.085  ...        41.2       35973.781
# ...

# %%
covid_df.shape
# Out:
# (205, 25)

# %%
covid_df.dtypes
# Out:
# continent                                   object
# location                                    object
# total_deaths                               float64
# date                                        object
# total_deaths_per_million                   float64
# stringency_index                           float64
# population_density                         float64
# median_age                                 float64
# gdp_per_capita                             float64
# aged_65_older                              float64
# life_expectancy                            float64
# human_development_index                    float64
# total_cases                                float64
# stringency_index                           float64
# population_density                         float64
# median_age                                 float64
# gdp_per_capita                             float64
# aged_65_older                              float64
# ...

# %%
covid_df['log_life'] = np.log(covid_df['Life expectancy at birth, total (years)'] + 1)
covid_df['log_death'] = np.log(covid_df['total_deaths'] + 1)

# %%
#covid_df['life_curr'] = np.log(covid_df['life_expectancy'] + 1)

# %%
plt.figure(figsize=(10, 10))
sns.regplot(x="log_life", y='log_death', data=covid_df)
# Out:
# <AxesSubplot:xlabel='log_life', ylabel='log_death'>

# %%
#from linearmodels.panel import PanelOLS
#mod = PanelOLS(df.y, df.x, entity_effects=True)
#res = mod.fit(cov_type='clustered', cluster_entity=True)
#print(res)

# %%
import sys
print(sys.version)
# Out:
# 3.7.3 (default, Mar 27 2019, 16:54:48)
# [Clang 4.0.1 (tags/RELEASE_401/final)]

# %%
import statsmodels.api as sm
from statsmodels.sandbox.regression.predstd import wls_prediction_std

# %%
covid_df.head()
# Out:
#        continent     location  total_deaths        date  \
# 0  North America        Aruba          34.0  2020-10-20
# 1           Asia  Afghanistan        1497.0  2020-10-20
# 2         Africa       Angola         247.0  2020-10-20
# 3  North America     Anguilla           NaN  2020-10-20
# 4         Europe      Albania         454.0  2020-10-20
#
#    total_deaths_per_million  stringency_index  population_density  median_age  \
# 0                   318.453               NaN             584.800        41.2
# 1                    38.455               NaN              54.422        18.6
# 2                     7.515               NaN              23.890        16.8
# 3                       NaN               NaN                 NaN         NaN
# 4                   157.759               NaN             104.871        38.0
#
#    gdp_per_capita  aged_65_older  ...  aged_65_older  life_expectancy  \
# 0       35973.781         13.085  ...         13.085            76.29
# ...

# %%
covid_df.columns
# Out:
# Index(['continent', 'location', 'total_deaths', 'date',
#        'total_deaths_per_million', 'stringency_index', 'population_density',
#        'median_age', 'gdp_per_capita', 'aged_65_older', 'life_expectancy',
#        'human_development_index', 'total_cases', 'stringency_index',
#        'population_density', 'median_age', 'gdp_per_capita', 'aged_65_older',
#        'life_expectancy', 'human_development_index', 'total_cases', 'Entity',
#        'Code', 'Life expectancy at birth, total (years)',
#        'Total population (Gapminder, HYDE & UN)', 'log_life', 'log_death'],
#       dtype='object')

# %%
#covid_df.dropna(inplace=True)

# %%
covid_reg = covid_df[['log_death' ,'log_life','population_density', 'median_age', 'gdp_per_capita', 'aged_65_older', 'life_expectancy']]
covid_reg.dropna(inplace=True)
covid_reg.shape
# Out:
# /Users/uzomailoanugo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# (160, 12)

# %%
X = covid_reg[['log_life']]
y = covid_reg['log_death']

# %%
X = sm.add_constant(X)

# %%
model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              log_death   R-squared:                       0.033
# Model:                            OLS   Adj. R-squared:                  0.027
# Method:                 Least Squares   F-statistic:                     5.389
# Date:                Sat, 31 Oct 2020   Prob (F-statistic):             0.0215
# Time:                        11:27:56   Log-Likelihood:                -366.05
# No. Observations:                 160   AIC:                             736.1
# Df Residuals:                     158   BIC:                             742.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.9013      3.488     -0.545      0.586      -8.790       4.988
# ...
